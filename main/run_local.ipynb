# %%
import os
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

import os
import sys
code_path = os.path.dirname(os.path.abspath('.'))
print(code_path)
# Out:
# c:\Users\jihun\python practices\pbcnet\PBCNet2.0
